# %%
import pandas as pd
# Import Data
spotifyData = pd.read_csv('data1.csv')


# Drop label and irrelevant classes
x = spotifyData.drop(['target','song_title', 'serial_num', 'mode', 'key', 'duration_ms' ], axis=1)
y = spotifyData['target']

# %%
x.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0102         0.833   0.434          0.021900    0.1650    -8.795
# 1        0.1990         0.743   0.359          0.006110    0.1370   -10.401
# 2        0.0344         0.838   0.412          0.000234    0.1590    -7.148
# 3        0.6040         0.494   0.338          0.510000    0.0922   -15.236
# 4        0.1800         0.678   0.561          0.512000    0.4390   -11.648
#
#    speechiness    tempo  time_signature  valence            artist
# 0       0.4310  150.062             4.0    0.286            Future
# 1       0.0794  160.083             4.0    0.588  Childish Gambino
# 2       0.2890   75.044             4.0    0.173            Future
# 3       0.0261   86.468             4.0    0.230       Beach House
# 4       0.0694  174.004             4.0    0.904       Junior Boys

# %%
from sklearn import preprocessing
x["artist"] = x["artist"].astype('category')
x["artist"] = x["artist"].cat.codes
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x = pd.DataFrame(x_scaled)




from sklearn.model_selection import train_test_split
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=69)
